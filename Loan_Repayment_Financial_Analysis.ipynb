# %% [markdown]
# <a href="https://colab.research.google.com/github/Nachoxt17/Loan-Repayment-Financial-Analysis/blob/main/Loan_Repayment_Financial_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Load Data

# %%
# Installing basic dependencies:
# !pip install opendatasets
# !pip install pandas

# %%
# Importing basic dependencies:
# import opendatasets as od
import pandas as pd
import numpy as np

# %%
# Importing DataSet:
dataset_url = "https://raw.githubusercontent.com/Nachoxt17/Loan-Repayment-Financial-Analysis/main/loan_borrower_data.csv"
# od.download(dataset_url)

df = pd.read_csv(dataset_url)

df.head(5)
# Out:
#   The purpose of the loan.  \
# 0                  Purpose
# 1       debt_consolidation
# 2              credit_card
# 3       debt_consolidation
# 4       debt_consolidation
#
#   The interest rate of the loan (more risky borrowers are assigned higher interest rates).  \
# 0                                               Rate
# 1                                             0.1189
# 2                                             0.1071
# 3                                             0.1357
# 4                                             0.1008
#
#   The monthly installments owed by the borrower if the loan is funded.  \
# 0                                         Instalment
# 1                                              829.1
# 2                                             228.22
# 3                                             366.86
# 4                                             162.34
#
#   The FICO credit score of the borrower.  \
# 0                                  Score
# ...

# %%
df.columns = df.iloc[0]
df = df[1:]
df = df.reset_index(drop=True)

# %%
df.head(5)
# -The Purpose of the Loan.
# -The Interest Rate of the Loan (more rusky borrowers are assigned higher rates).
# -The Monthly Installments owed by the borrower if the loan is funded.
# -The F.I.C.O. credit score of the borrower.
# -The number of days the borrower has had a credit line.
# -The borrower's number of inquiries by creditors in the last 6 months.
# -The number of times the borrower had been 30+ days past due on a payment in the past 2 years.
# -1 if the loan is *NOT* fully paid.
# Out:
# 0             Purpose    Rate Instalment Score Days_Credit Inquiries  \
# 0  debt_consolidation  0.1189      829.1   737        5640         0
# 1         credit_card  0.1071     228.22   707        2760         0
# 2  debt_consolidation  0.1357     366.86   682        4710         1
# 3  debt_consolidation  0.1008     162.34   712        2700         1
# 4         credit_card  0.1426     102.92   667        4066         0
#
# 0 Delay_2yrs Fully_Paid
# 0          0        Yes
# 1          0        Yes
# 2          0        Yes
# 3          0        Yes
# 4          1        Yes

# %% [markdown]
# ---

# %% [markdown]
# # Data Type

# %%
numerical_col = ['Rate', 'Instalment','Score','Days_Credit','Inquiries','Delay_2yrs']

def check_datatype(df , numerical_col):
    for col in numerical_col:
        print(col, ":", df[col].dtype)

# %%
check_datatype(df , numerical_col)
# Out:
# Rate : object
# Instalment : object
# Score : object
# Days_Credit : object
# Inquiries : object
# Delay_2yrs : object

# %%
def convertor(df , numerical_col):
    for col in numerical_col:
        df[col]=df[col].astype(float)

# %%
convertor(df , numerical_col)

# %%
check_datatype(df , numerical_col)
# Out:
# Rate : float64
# Instalment : float64
# Score : float64
# Days_Credit : float64
# Inquiries : float64
# Delay_2yrs : float64

# %% [markdown]
# ---

# %% [markdown]
# # Target Variable

# %%
df['Fully_Paid'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Fully_Paid'] = df['Fully_Paid'].replace({'Yes':1,'No':0})
# Out:
# <ipython-input-12-c100b8593094>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Fully_Paid'] = df['Fully_Paid'].replace({'Yes':1,'No':0})

# %%
df['Fully_Paid'].unique()
# Out:
# array([1, 0])

# %% [markdown]
# ---

# %% [markdown]
# # Correlation Numerical ~ Target

# %%
from scipy.stats import pointbiserialr

numerical_col = ['Rate', 'Instalment','Score','Days_Credit','Inquiries','Delay_2yrs']
target = 'Fully_Paid'

correlation = {}

for col in numerical_col:
    corr, _ = pointbiserialr(df[col], df[target])
    correlation[col] = corr

correlation_df = pd.DataFrame(list(correlation.items()), columns=['Variable', 'Correlation']).sort_values(by='Correlation', ascending = False)

# %%
correlation_df
# Out:
#       Variable  Correlation
# 2        Score     0.191202
# 5   Delay_2yrs     0.110748
# 3  Days_Credit     0.082810
# 1   Instalment    -0.082602
# 4    Inquiries    -0.106988
# 0         Rate    -0.274115

# %% [markdown]
# ---

# %% [markdown]
# # Correlation Categorical ~ Target

# %%
from scipy.stats import chi2_contingency

categorical_col = ['Purpose']
target = 'Fully_Paid'

chi2_results = {}

for col in categorical_col:
    crosstab = pd.crosstab(df[col], df[target])
    chi2, p, _, _ = chi2_contingency(crosstab)
    chi2_results[col] = (chi2, p)

chi2_result_df = pd.DataFrame(list(chi2_results.items()) , columns=['Variable', 'Chi2_p'])

# %%
chi2_result_df
# Out:
#   Variable                                    Chi2_p
# 0  Purpose  (8.810452832191963, 0.18452203894824112)

# %% [markdown]
# ---
